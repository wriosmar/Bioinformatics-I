# %%
def pattern_matching(text, pattern):
    index = []
    for i in range((len(text) + 1) - len(pattern)):
        if text[i: (len(pattern) + i)] == pattern:
            index.append(i)
    return index

# %%
print(pattern_matching("...", "TGTTTGTTG"))
# Out:
# [18, 34, 57, 94, 185, 223, 238, 271, 291, 313, 342, 349, 410, 526, 533, 540, 555, 562, 577, 623, 666, 673, 743, 780, 789, 817, 824, 842, 894, 901, 912, 944, 1034, 1079, 1086, 1133, 1165, 1251, 1258, 1265, 1272, 1344, 1374, 1427, 1434, 1441, 1448, 1466, 1482, 1527, 1563, 1570, 1657, 1664, 1681, 1724, 1731, 1740, 1830, 1839, 1861, 1912, 1964, 2135, 2188, 2205, 2279, 2305, 2312, 2410, 2436, 2447, 2504, 2548, 2601, 2622, 2873, 2880, 2887, 2958, 2969, 2994, 3063, 3142, 3166, 3228, 3235, 3273, 3280, 3287, 3310, 3317, 3351, 3358, 3375, 3390, 3445, 3452, 3569, 3605, 3612, 3619, 3674, 3681, 3688, 3745, 3761, 3953, 3960, 3983, 4053, 4077, 4094, 4247, 4263, 4270, 4317, 4410, 4425, 4441, 4457, 4464, 4471, 4502, 4599, 4609, 4616, 4623, 4715, 4770, 4787, 4886, 4893, 4935, 4964, 4992, 4999, 5017, 5024, 5135, 5174, 5279, 5394, 5411, 5418, 5462, 5560, 5661, 5686, 5693, 5731, 5746, 5753, 5778, 5785, 5805, 5845, 5883, 5899, 5974, 5981, 6004, 6027, 6112, 6281, 6298, 6350, 6465, 6527, 6552, 6587, 6813, 6
# ...
